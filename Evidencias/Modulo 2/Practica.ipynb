# %%
import pandas as pd

# %%
employees = pd.read_csv("Datasets/employees.csv", index_col="First Name", parse_dates=["Start Date"])
employees.sort_index(inplace=True)

# %%
employees
# Out:
#             Gender Start Date Last Login Time  Salary  Bonus %  \
# First Name
# Aaron         Male 2012-02-17        10:20 AM   61602   11.849
# Aaron         Male 1994-01-29         6:48 PM   58755    5.097
# Aaron         Male 1990-07-22         2:53 PM   52119   11.343
# Aaron          NaN 1986-01-22         7:39 PM   63126   18.424
# Adam          Male 2011-05-21         1:45 AM   95327   15.120
# ...            ...        ...             ...     ...      ...
# NaN           Male 2001-05-23         7:52 PM  103877    6.322
# NaN         Female 2000-08-23         4:19 PM   95866   19.388
# NaN         Female 1985-09-15         1:50 AM  133472   16.941
# NaN           Male 2012-07-30         3:07 PM  107351    5.329
# NaN         Female 2010-09-14         5:19 AM  143638    9.662
#
#            Senior Management             Team
# First Name
# Aaron                   True        Marketing
# Aaron                   True        Marketing
# ...

# %%
# Generar un reporte con filtros que contengan los registros de los empleados masculinos y marketing

# %%
employees.query("Gender=='Male' and Team=='Marketing'").head()
# Out:
#            Gender Start Date Last Login Time  Salary  Bonus %  \
# First Name
# Aaron        Male 2012-02-17        10:20 AM   61602   11.849
# Aaron        Male 1994-01-29         6:48 PM   58755    5.097
# Arthur       Male 2014-12-16         4:56 PM   66819    6.639
# Benjamin     Male 1984-09-11         6:37 AM   84810   15.794
# Charles      Male 2004-09-14         8:13 PM  107391    1.260
#
#            Senior Management       Team
# First Name
# Aaron                   True  Marketing
# Aaron                   True  Marketing
# Arthur                  True  Marketing
# Benjamin               False  Marketing
# Charles                 True  Marketing

# %%
#filtrar empleados que son parte de Senior management o que empezaron antes del 1990

mask1 = employees["Senior Management"]= True
mask2 = employees["Start Date"]<"12-31-1989"
#employees[mask2]
employees[(mask1) | (mask2)]
# Out:
#             Gender Start Date Last Login Time  Salary  Bonus %  \
# First Name
# Aaron         Male 2012-02-17        10:20 AM   61602   11.849
# Aaron         Male 1994-01-29         6:48 PM   58755    5.097
# Aaron         Male 1990-07-22         2:53 PM   52119   11.343
# Aaron          NaN 1986-01-22         7:39 PM   63126   18.424
# Adam          Male 2011-05-21         1:45 AM   95327   15.120
# ...            ...        ...             ...     ...      ...
# NaN           Male 2001-05-23         7:52 PM  103877    6.322
# NaN         Female 2000-08-23         4:19 PM   95866   19.388
# NaN         Female 1985-09-15         1:50 AM  133472   16.941
# NaN           Male 2012-07-30         3:07 PM  107351    5.329
# NaN         Female 2010-09-14         5:19 AM  143638    9.662
#
#             Senior Management             Team
# First Name
# Aaron                    True        Marketing
# Aaron                    True        Marketing
# ...

# %%
pd.__version__
# Out:
# '2.3.3'

# %%
# Filtrar los empleados que se llaman Robert, 
# que son parte de client Services o que empezaron despues de junio de 2016
