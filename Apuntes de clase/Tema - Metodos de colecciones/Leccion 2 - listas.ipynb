# %%
lista=[1,2,3,4,5]

# %%
lista.clear()
lista

# %%
l1=[1,2,3]
l2=[4,5,6]
l1.extend(l2)

# %%
l1.count(2)
# Out:
# 1

# %%
l=[1,2,3]
l.insert(0,0) # Insertar 0 en posicion 0
l
l.insert(5,6)

# %%
l
# Out:
# [0, 1, 2, 3, 6]

# %%
l=[5,10,15,25]
l.insert(-1,6)

# %%
l
# Out:
# [5, 10, 15, 6, 25]

# %%
l=[10,20,30,40,50]

# %%
l.pop()
l
# Out:
# [10, 20, 30, 40]

# %%
l.pop(0)
l
# Out:
# [20, 30, 40]

# %%
l.remove(30)
# Con remove se indica el valor del elemento a remover a diferenciad e pop que recive el indice
l
# Out:
# [20, 40]

# %%
l
# Out:
# [20, 40]

# %%
l.reverse()
l
# Out:
# [20, 40]

# %%
lista=list("Hola Mundo")

# %%
lista
# Out:
# ['H', 'o', 'l', 'a', ' ', 'M', 'u', 'n', 'd', 'o']

# %%
lista.reverse()

# %%
lista
# Out:
# ['o', 'd', 'n', 'u', 'M', ' ', 'a', 'l', 'o', 'H']

# %%
cadena="".join(lista)

x=""
x.join("awdawd")
x
# Out:
# ''

# %%
cadena
# Out:
# 'odnuM aloH'

# %%
cadena="_".join(lista)

# %%
cadena
# Out:
# 'o_d_n_u_M_ _a_l_o_H'

# %%
lista=[5,3,6,7,-12,-56]

# %%
lista.sort() #Ordena de menor a mayor

# %%
lista
# Out:
# [-56, -12, 3, 5, 6, 7]

# %%
lista.sort(reverse=True) # Ordena de mayor a menor

# %%
lista
# Out:
# [7, 6, 5, 3, -12, -56]
