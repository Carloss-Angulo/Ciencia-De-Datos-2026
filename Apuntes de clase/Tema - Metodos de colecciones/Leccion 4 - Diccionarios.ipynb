# %% [markdown]
# Diccionarios

# %%
colores={"amarillo":"yellow", "azul": "blue", "negro": "black"}

Alumno={"Nombre":"Luis", "Apellido":"Lopez"}

colores["negro"]
# Out:
# 'black'

# %%
# Se dispara un default cuando no se encuentra
colores.get('rojo', 'no se encuentra')
# Out:
# 'no se encuentra'

# %%
'blue' in colores
# Out:
# False

# %%
'amarillo' in colores
# Out:
# True

# %%
colores.keys()
# Out:
# dict_keys(['amarillo', 'azul', 'negro'])

# %%
colores.values()
# Out:
# dict_values(['yellow', 'blue', 'black'])

# %%
colores.items()
# Out:
# dict_items([('amarillo', 'yellow'), ('azul', 'blue'), ('negro', 'black')])

# %%
colores
# Out:
# {'amarillo': 'yellow', 'azul': 'blue', 'negro': 'black'}

# %%
for c in colores:
    print(c)
# Out:
# amarillo
# azul
# negro

# %%
for c in colores.keys():
    print(c)
# Out:
# amarillo
# azul
# negro

# %%
for k,v in colores.items():
    print(k,v)
# Out:
# amarillo yellow
# azul blue
# negro black

# %%
colores.pop('amarillo', 'no se encuentra')
# Out:
# 'no se encuentra'

# %%
colores.clear()

# %%
colores
# Out:
# {}
