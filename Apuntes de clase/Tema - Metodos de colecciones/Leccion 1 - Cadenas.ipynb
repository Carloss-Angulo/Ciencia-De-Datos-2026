# %%
C="Hola Mundo"

# %%
C.upper()
# Out:
# 'HOLA MUNDO'

# %%
C.lower()
# Out:
# 'hola mundo'

# %%
C.capitalize()
#Primer letra en Mayusculas
# Out:
# 'Hola mundo'

# %%
C.title()
#Todas las iniciales en mayusculas
# Out:
# 'Hola Mundo'

# %%
C.count('o')
# Out:
# 2

# %%
C.count('Hola')
# Out:
# 1

# %%
B="Hola mundo como estas ahora el mundo, dime Hola por favor mundo"
B.count('mundo')
# Out:
# 3

# %%
B.find("mundo")
# Out:
# 5

# %%
B="mundo mundo mundo mundo"
# Out:
# 'm'

# %%
B.rfind('mundo')
# Out:
# 58

# %%
A="100"

# %%
A.isdigit()
# Out:
# True

# %%
C2="ABC100wa"

# %%
C2.isalnum()
# Out:
# True

# %%
C2.isalpha()
# Out:
# False

# %%
C="Hola mundo"
C.islower()
# Out:
# False

# %%
"Hola mundo".islower()
# Out:
# False

# %%
"  ".isspace()
# Out:
# True

# %%
" A ".isspace()
# Out:
# False

# %%
"Hola Mundo".startswith("H")
# Out:
# True

# %%
"Hola Mundo".startswith("Hola")
# Out:
# True

# %%
"Hola Mundo".endswith("o")
# Out:
# True

# %%
H="Hola Mundo".split()
#separa el string a base es espacion en una lista

# %%
H
# Out:
# ['Hola', 'Mundo']

# %%
"Hola mundo".split()[1]
# Out:
# 'mundo'

# %%
"Hola mundo, Hola, mundo, Hola mundo".split(",")
# Out:
# ['Hola mundo', ' Hola', ' mundo', ' Hola mundo']

# %%
" ".join("Hola")
# Out:
# 'H o l a'

# %%
"--------- Hola Mundo ------".strip("-")

#Elimina caracteres no deseados
# Out:
# ' Hola Mundo '

# %%
" Hola Mundo  ".strip()
# Out:
# 'Hola Mundo'

# %%
"Hola Mundo".replace('o', '0')
# Out:
# 'H0la Mund0'

# %%
"Hola Mundo".replace("Mundo", "Marte")
# Out:
# 'Hola Marte'
