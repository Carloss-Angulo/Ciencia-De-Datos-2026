# %%
'Hola'

# %%
"Hola Mundo"

# %%
'Este texto incluye unas comillas " "'

# %%
"Esta 'palanra' Se encuentra entre comillas simples"

# %%
"Esa "palabra" se encuentra entre comillas dobles"
# Out:
#   Cell In[1], line 1
#     "Esa "palabra" se encuentra entre comillas dobles"
#           ^
# SyntaxError: invalid syntax

# %%
"una cadena"
'una cadena'

# %%
print("Esto es una cadena")
# Out:
# Esto es una cadena

# %%
print("Un texto/tEsto es tabulacion")
# Out:
# Un texto/tEsto es tabulacion

# %%
print("Un testo /n una nueva linea")

# %%
print("C:/nombre/carpeta")

# %%
# r permite mostrar datos en crudo ... es decir la diagonal inversa tal como es


print(r"C:/nombre/carpeta")

# %%
c="Esto es una cadena /n con dos lineas"

# %%
print(c+c)

# %%
s="Una cadena" "Compuesta de 2 cadenas"

print(s)

# %%
c1= "Una cadena"
c2 = "Otra cadena"
c3 = c1 + c2
print(c3)

# %%
palabra="python"

# %%
palabra[0]

# %%
palabra[-1]

# %%
palabra[-2]

# %%
palabra[0:2]

# sirve apra substraer una cadena, primer parametro inclusivo, ultimo exclusivo del rango

# %%
palabra[:]
# si no indicamos el rango se retorna todo

# %%
palabra[99]

# Indice fuera de rango

# %%
palabra[:99]

# como no llega a 99 se imprime toda la cadena

# %%
palabra= "n" + palabra[1:]

# %%
len(palabra)
