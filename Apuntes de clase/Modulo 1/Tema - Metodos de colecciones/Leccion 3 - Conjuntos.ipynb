# %%
#CONJUNTOS DISJUNTOS CONJUNTOS CONTENEDORES DE OTROS SUBCONJUNTOS

c={1,2,3,4,5}

c1={1,2,3}
c2={3,4,5}
c3={-1,99}
c4={1,2,3,4,5,}

c.isdisjoint(c2)
# Out:
# False

# %%
c3.isdisjoint(c4)
# Out:
# True

# %%
#Es subconjunto de otro conjunto

c.issubset(c4)
# Out:
# True

# %%
c2.issubset(c4)
# Out:
# True

# %%
c4.issuperset(c)
# Out:
# True

# %%
c1.union(c2)==c4
# Out:
# True

# %%
#Pega el conjunto 2 al conjunto 1
c1.update(c2)

# %%
c1={1,2,3}
c2={}

# %% [markdown]
# Subir imagenes de cada punto del proyecto, capturas del mismo tamaño, añadir link depo github al doc
#
# Dentro del repo crear carpetas: modulo1,2,3,4,etc
#
# Dar acceso a la red:
#
# zuriel.mf@culiacan.tecnm.mx
