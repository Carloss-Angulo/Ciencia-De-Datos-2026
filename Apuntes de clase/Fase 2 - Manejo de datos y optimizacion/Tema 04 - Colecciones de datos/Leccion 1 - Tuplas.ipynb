# %%
tupla = (100,"Hola", [1,2,3,4], -50)
tupla
# Out:
# (100, 'Hola', [1, 2, 3, 4], -50)

# %%
tupla[-1]
# Out:
# -50

# %%
tupla[0:]
# Out:
# (100, 'Hola', [1, 2, 3, 4], -50)

# %%
tupla[2][-1]

# %%
## Diferencia de lista y tupla
## Las tuplas son imutables, no pueden cambiar su valor despues de su creacion

# %%
len(tupla)
# Out:
# 4

# %%
len(tupla[2])
# Out:
# 4

# %%
tupla.index(100)
# Out:
# 0

# %%
tupla.index("Hola")
# Out:
# 1

# %%
tupla.count(100) #Cuantas veces aparece 100?

# %%
tupla=(100,100,100)
tupla.count(100)
# Out:
# 3

# %%
lista = [1,1,3,4,5,6]
lista
lista.count(1)
# Out:
# 2
